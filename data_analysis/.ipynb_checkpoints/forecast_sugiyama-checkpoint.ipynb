# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()

# %%
df = pd.read_csv('sgym_ship.csv', encoding = 'Shift-JIS')
df.columns = ['date','qty']
df["date"] = pd.to_datetime(df["date"])
df = df.set_index("date").sort_index()
df.head()
# Out:
#                 qty
# date
# 2018-04-04  41296.0
# 2018-04-05  38153.0
# 2018-04-06  33987.0
# 2018-04-07   9665.0
# 2018-04-08      0.0

# %%
df.plot(style=".",figsize=(20,8), color=color_pal[0])

# %%
df.describe()
# Out:
#                  qty
# count    1549.000000
# mean    30281.402195
# std     20598.304323
# min         0.000000
# 25%     12283.000000
# 50%     32534.000000
# 75%     42086.000000
# max    146764.000000

# %% [markdown]
# # Analysis

# %%
def feature_crt(df):
    """
    Create date features using dataframe with date index
    """
    df = df.copy()
    df["year"] = df.index.year
    df["month"] = df.index.month
    df["day"] = df.index.day
    df["dow"] = df.index.dayofweek
    df["doy"] = df.index.dayofyear
    
    return df
df_proc = feature_crt(df)

# %%
grouped = df_proc.groupby(["year","month"]).qty.sum()

fig, axes = plt.subplots(5,1,figsize=(10,8),sharex=True)

for ax, yr in zip(axes, df_proc["year"].unique()):
    ax.plot(grouped[yr], label=f"{yr}")
    ax.set_xticks(range(1,13))
    ax.set_xticklabels([i+1 for i in range(12)])
    ax.legend()

plt.show()

# %% [markdown]
# Looking at the above graph, we can see that there is a common pattern of a peak in March and June, followed by another uptick in September.

# %%
# group_by_day = df_proc.groupby("day").qty.mean()
fig, ax = plt.subplots(figsize=(10,5))
sns.boxplot(ax=ax, data=df_proc, x="day",y="qty")
plt.show()

# %% [markdown]
# There seems to be a pattern of higher demand at the beginning and end of the month

# %%
group_by_dow = df_proc.groupby("dow").qty.mean()

fig, ax = plt.subplots(figsize=(10,5))
# ax.plot(group_by_dow, color=color_pal[2])
sns.boxplot(ax=ax, data=df_proc, x="dow",y="qty")
ax.set_xticks(range(7))
ax.set_xticklabels(["mon","tue","wed","thu","fri","sat","sun"])
ax.set_title("Average demand by day of week")
plt.show()

# %% [markdown]
# Looking at average demand by day of week, we see that demand is usually highest at week beginning and lower towards the weekend

# %%
grouped.plot(figsize=(15,5))

# %% [markdown]
# # Train Test Split

# %%
# Create train and test data, keeping 1 month of data for holdout
holdout_idx = "2022-06-01"
train = df.loc[df.index < "2021-07-01"]
test = df.loc[(df.index >= "2021-07-01") & (df.index < holdout_idx)]
holdout = df.loc[df.index >= holdout_idx]

fig, ax = plt.subplots(figsize=(15,5))
ax.plot(train, label="train")
ax.plot(test, label="test")
ax.axvline(pd.to_datetime('2021-07-01'), color="black", ls="--")
ax.set_title("Train/Test Split")
plt.legend()
plt.show()

# %% [markdown]
# ### Create features

# %%
train = feature_crt(train)
test = feature_crt(test)

FEATURES = ["year","month","day","dow","doy"]
TARGET = "qty"

# %%
X_train = train[FEATURES]
y_train = train[TARGET]
X_test = test[FEATURES]
y_test = test[TARGET]

# %%
holdout = feature_crt(holdout)
X_holdout = holdout[FEATURES]
y_holdout = holdout[TARGET]

# %% [markdown]
# # Model Creation

# %%
class XGBRegressorExtended(xgb.XGBRegressor):
    """
    Custom Regressor class for forecasting values
    """
    def predict_transform(self, xtest):
        yt = self.predict(xtest)
        yt[yt<0] = 0
        return yt

# %%
# reg = xgb.XGBRegressor(n_estimators=1000, early_stopping_rounds=50, learning_rate=0.01)
reg = XGBRegressorExtended(n_estimators=1000, early_stopping_rounds=50, learning_rate=0.01)
reg.fit(X_train, y_train, 
       eval_set=[(X_train, y_train), (X_test, y_test)],
       verbose=100)
# Out:
# [02:20:13] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:37357.93359	validation_1-rmse:32167.13086
# [100]	validation_0-rmse:16757.06836	validation_1-rmse:13845.70019
# [200]	validation_0-rmse:10418.25195	validation_1-rmse:10058.68457
# [300]	validation_0-rmse:8407.15430	validation_1-rmse:9816.87500
# [400]	validation_0-rmse:7468.81787	validation_1-rmse:9909.88965
# [500]	validation_0-rmse:6829.69336	validation_1-rmse:9993.91016
# [600]	validation_0-rmse:6349.59033	validation_1-rmse:10102.30664
# [700]	validation_0-rmse:5953.82959	validation_1-rmse:10257.54590
# [800]	validation_0-rmse:5626.75000	validation_1-rmse:10393.28516
# [900]	validation_0-rmse:5343.10449	validation_1-rmse:10468.75391
# [999]	validation_0-rmse:5104.24853	validation_1-rmse:10616.41113
# XGBRegressorExtended(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                      colsample_bynode=1, colsample_bytree=1,
#                      early_stopping_rounds=50, enable_categorical=False,
#                      gamma=0, gpu_id=-1, importance_type=None,
#                      interaction_constraints='', learning_rate=0.01,
#                      max_delta_step=0, max_depth=6, min_child_weight=1,
#                      missing=nan, monotone_constraints='()', n_estimators=1000,
#                      n_jobs=12, num_parallel_tree=1,
#                      objective='reg:squarederror', predictor='auto',
#                      random_state=0, reg_alpha=0, reg_lambda=1,
#                      scale_pos_weight=1, subsample=1, tree_method='exact',
#                      validate_parameters=1, verbosity=None)

# %%
feat_imp = pd.DataFrame(data=reg.feature_importances_,
             index=reg.get_booster().feature_names,
             columns=['importance'])
feat_imp.sort_values('importance').plot(kind='barh', title="Feature Importance")
plt.show()

# %% [markdown]
# # Predict on Test

# %%
# test['prediction'] = reg.predict_transform(X_test)
holdout['prediction'] = reg.predict_transform(X_holdout)
# test['prediction'] = reg.predict(X_test)
if "prediction" in df_proc.columns:
    df_proc.drop("prediction", axis=1, inplace=True)
df_proc = df_proc.merge(holdout[['prediction']], how="left",left_index=True,right_index=True) #2 brackets -> dataframe instead of series

fig, ax = plt.subplots(figsize=(15,5))
ax.plot(df_proc[["qty"]], label="Truth")
ax.plot(df_proc[["prediction"]],label="Prediction")
ax.set_title("Truth vs Prediction")
plt.show()

# %%
#Check for 1 month
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(df_proc.loc[(df_proc["year"]==2022) & (df_proc["month"]==6)].qty, label="Truth")
ax.plot(df_proc.loc[(df_proc["year"]==2022) & (df_proc["month"]==6)].prediction,marker="o",label="Prediction")
plt.xticks(rotation=45)
ax.legend()
plt.show()

# %%
print(np.sqrt(mean_squared_error(holdout['qty'], holdout['prediction'])))
print(holdout["qty"].mean())

from sklearn.metrics import mean_absolute_error as mae
print(mae(holdout["qty"], holdout["prediction"]) / holdout["qty"].mean())
# Out:
# 12814.025810630465
# 31037.2
# 0.2847613960331566

# %% [markdown]
# # Create Lag Feature

# %%
# How to create lag features
# Decide lag: 28 days
# Get lagged date and lagged values
# Below is the naive way. There is a better way using Series.map below
# df_lagged = df.copy()
# df_lagged.index = df.index + pd.Timedelta(days=28)
# df_lagged.rename(columns={"qty":"lag_28_d"}, inplace=True)
# df.merge(df_lagged, how="left", left_index=True, right_index=True)

# %%
def lag_features(df, val_col: str = "qty", lag_period: int = 28, multiplier: int = 3):
    """
    Return df with lag features added
    lag_period: lag period in days
    multiplier: specify number of lag features to be created, which will be a multiplier of the lag_period.
    """
    df_lagged = df.copy()
    for i in range(lag_period, lag_period*(multiplier+1), lag_period):
        if f"lag{i}d" in df_lagged.columns:
            df_lagged.drop(f"lag{i}d", axis=1, inplace=True)
        df_lagged[f"lag{i}d"] = (df.index - pd.Timedelta(f"{i} days")).map(df[val_col])
    
    return df_lagged

# %%
df = lag_features(df, "qty")
df.head()
# Out:
#                 qty  lag28d  lag56d  lag84d
# date
# 2018-04-04  41296.0     NaN     NaN     NaN
# 2018-04-05  38153.0     NaN     NaN     NaN
# 2018-04-06  33987.0     NaN     NaN     NaN
# 2018-04-07   9665.0     NaN     NaN     NaN
# 2018-04-08      0.0     NaN     NaN     NaN

# %% [markdown]
# # Improve with cross validation

# %%
def ts_split(df_input, holdout_idx, fold, gap):
    
    df = df_input[df_input.index <= holdout_idx]
    max_idx = len(df.index)-1
    train_idx = [idx for idx in df.index if idx < df.index[max_idx-gap*(fold+1)]]
    val_idx = [idx for idx in df.index if idx >= df.index[max_idx-gap*(fold+1)] and idx <= df.index[max_idx-gap*fold]]
    
    return train_idx, val_idx

# %%
fig, axes = plt.subplots(5, 1, figsize=(15,15), sharex=True)
for fold in range(5):
    train_idx, val_idx = ts_split(df, holdout_idx, fold, gap=90)
    train = df.loc[train_idx]
    test = df.loc[val_idx]
    axes[fold].plot(train["qty"], label="Training Set")
    axes[fold].plot(test["qty"], label="Test Set")
    axes[fold].axvline(test.index.min(), color="black", ls="--")
    axes[fold].legend()

plt.show()

# %%
holdout = df.loc[df.index >= holdout_idx]
holdout = feature_crt(holdout)

preds = []
scores_rmse = []
scores_mae = []
for fold in range(5):
    train_idx, val_idx = ts_split(df, holdout_idx, fold, gap=90)
    train_cv = df.loc[train_idx]
    test_cv = df.loc[val_idx]
    train_cv = feature_crt(train_cv)
    test_cv = feature_crt(test_cv)

    FEATURES = [col for col in df.columns if col != "qty"]
    TARGET = "qty"
    
    X_train_cv = train_cv[FEATURES]
    y_train_cv = train_cv[TARGET]
    X_test_cv = test_cv[FEATURES]
    y_test_cv = test_cv[TARGET]
    X_holdout = holdout[FEATURES]
    y_holdout = holdout[TARGET]
    
    
    reg_cv = XGBRegressorExtended(n_estimators=1000, early_stopping_rounds=50, learning_rate=0.01)
    reg_cv.fit(X_train_cv, y_train_cv, 
           eval_set=[(X_train_cv, y_train_cv), (X_test_cv, y_test_cv)],
           verbose=100)
    y_pred = reg_cv.predict_transform(X_holdout)
    preds.append(y_pred)
    score_rmse = np.sqrt(mean_squared_error(y_holdout, y_pred))
    scores_rmse.append(score_rmse)
    score_mae = mae(y_holdout, y_pred)
    scores_mae.append(score_mae)
# Out:
# [02:20:17] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:36662.79297	validation_1-rmse:29877.98047
# [100]	validation_0-rmse:17353.11328	validation_1-rmse:12310.42578
# [200]	validation_0-rmse:11874.40820	validation_1-rmse:8420.32227
# [300]	validation_0-rmse:10363.16504	validation_1-rmse:8209.59570
# [400]	validation_0-rmse:9636.67969	validation_1-rmse:8397.80859
# [500]	validation_0-rmse:9051.09570	validation_1-rmse:8595.38574
# [600]	validation_0-rmse:8629.30762	validation_1-rmse:8647.02246
# [700]	validation_0-rmse:8301.44336	validation_1-rmse:8673.48535
# [800]	validation_0-rmse:7949.35986	validation_1-rmse:8682.76660
# [900]	validation_0-rmse:7551.73877	validation_1-rmse:8710.23242
# [999]	validation_0-rmse:7239.38330	validation_1-rmse:8760.87402
# [02:20:19] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:37013.69141	validation_1-rmse:31053.58398
# [100]	validation_0-rmse:17503.63086	validation_1-rmse:14246.58203
# [200]	validation_0-rmse:11893.94238	validation_1-rmse:11579.56641
# [300]	validation_0-rmse:10413.95898	validation_1-rmse:11852.39844
# [400]	validation_0-rmse:9608.20801	validation_1-rmse:12103.03809
# [500]	validation_0-rmse:8990.03906	validation_1-rmse:12317.05859
# [600]	validation_0-rmse:8557.91797	validation_1-rmse:12456.83594
# [700]	validation_0-rmse:8167.22705	validation_1-rmse:12487.06250
# [800]	validation_0-rmse:7800.40430	validation_1-rmse:12600.09961
# [900]	validation_0-rmse:7456.73438	validation_1-rmse:12707.50488
# [999]	validation_0-rmse:7143.79639	validation_1-rmse:12812.77344
# [02:20:22] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:37267.58594	validation_1-rmse:33279.48438
# [100]	validation_0-rmse:17596.37109	validation_1-rmse:15577.01465
# [200]	validation_0-rmse:11919.43066	validation_1-rmse:11840.43945
# [300]	validation_0-rmse:10369.46777	validation_1-rmse:11325.39941
# [400]	validation_0-rmse:9563.90527	validation_1-rmse:11389.69629
# [500]	validation_0-rmse:8920.80859	validation_1-rmse:11626.15430
# [600]	validation_0-rmse:8379.55176	validation_1-rmse:11881.67871
# [700]	validation_0-rmse:7966.63184	validation_1-rmse:12113.10742
# [800]	validation_0-rmse:7615.89844	validation_1-rmse:12247.58496
# [900]	validation_0-rmse:7244.74658	validation_1-rmse:12434.21777
# [999]	validation_0-rmse:6904.66699	validation_1-rmse:12576.74707
# [02:20:24] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:37276.82812	validation_1-rmse:36959.63281
# [100]	validation_0-rmse:17413.67773	validation_1-rmse:20673.89258
# [200]	validation_0-rmse:11671.63281	validation_1-rmse:16934.03320
# [300]	validation_0-rmse:10165.55664	validation_1-rmse:16346.30078
# [400]	validation_0-rmse:9270.24316	validation_1-rmse:16211.59180
# [500]	validation_0-rmse:8655.28418	validation_1-rmse:16215.11523
# [600]	validation_0-rmse:8218.24512	validation_1-rmse:16273.15723
# [700]	validation_0-rmse:7816.04004	validation_1-rmse:16349.47754
# [800]	validation_0-rmse:7449.41504	validation_1-rmse:16478.89062
# [900]	validation_0-rmse:7122.12939	validation_1-rmse:16550.96289
# [999]	validation_0-rmse:6815.05029	validation_1-rmse:16608.11328
# [02:20:26] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:37504.23438	validation_1-rmse:34267.40234
# [100]	validation_0-rmse:17570.79492	validation_1-rmse:16194.24902
# [200]	validation_0-rmse:11811.17676	validation_1-rmse:11995.67285
# [300]	validation_0-rmse:10313.62598	validation_1-rmse:11395.55469
# [400]	validation_0-rmse:9486.70801	validation_1-rmse:11478.24902
# [500]	validation_0-rmse:8977.46289	validation_1-rmse:11590.85742
# [600]	validation_0-rmse:8561.42285	validation_1-rmse:11739.34082
# [700]	validation_0-rmse:8172.12939	validation_1-rmse:11865.11719
# [800]	validation_0-rmse:7723.45068	validation_1-rmse:11876.86035
# [900]	validation_0-rmse:7319.30859	validation_1-rmse:11866.22656
# [999]	validation_0-rmse:6982.94629	validation_1-rmse:11853.04688

# %%
scores_rmse
# Out:
# [11963.263793962013,
#  11211.44884323361,
#  11025.44878770534,
#  11438.826891769419,
#  12385.10306326349]

# %%
[x / holdout["qty"].mean() for x in scores_mae]
# Out:
# [0.24332284884965158,
#  0.22452089593042784,
#  0.2083730066175294,
#  0.22614892499569234,
#  0.2543005835611094]
